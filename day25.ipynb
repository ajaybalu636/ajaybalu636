# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
cars=pd.read_csv(r"/content/Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.describe
# Out:
# <bound method NDFrame.describe of      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]>

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
# Assuming you want to plot the distribution of the 'MPG' column:
import seaborn as sns

sns.distplot(cars['MPG'])
plt.show() # Display the plot

# OR

# If you want to use displot(), which is newer than distplot():
# Assuming you want to plot the distribution of the 'MPG' column:
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(cars['MPG'])
plt.show() # Display the plot

# OR

# If you want to use displot(), which is newer than distplot():
import seaborn as sns

sns.displot(cars['MPG'])
plt.show()

# %%
sns.distplot(cars['WT'])
plt.show()

# %%
sns.boxplot(cars['MPG'])
plt.show()

# %%
scatterplot=sns.scatterplot(x='MPG',y='WT',data=cars)
plt.show()

# %%
scatterplot=sns.scatterplot(x='MPG',y='HP',data=cars)
plt.show()

# %%
scatterplot=sns.scatterplot(x='MPG',y='SP',data=cars)
plt.show()

# %%
scatterplot=sns.scatterplot(x='HP',y='WT',data=cars)
plt.show()

# %%
scatterplot=sns.scatterplot(x='SP',y='WT',data=cars)
plt.show()

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap(cars.corr(),cmap='Blues',annot=True)
# Out:
# <Axes: >

# %%
scatterplot=sns.scatterplot(x='SP',y='HP',data=cars)
plt.show()

# %%
scatterplot=sns.scatterplot(x='VOL',y='HP',data=cars)
plt.show()

# %%
scatterplot=sns.scatterplot(x='VOL',y='WT',data=cars)
plt.show()
